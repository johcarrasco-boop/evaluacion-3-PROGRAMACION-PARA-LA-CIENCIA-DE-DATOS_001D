# %% [markdown]
# # Evaluación Parcial 3 — Demo pipeline end-to-end
# Este notebook ejecuta el ETL y revisa las tablas procesadas.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd()
sys.path.append(str(PROJECT_ROOT / "etl"))
from run_etl import run_pipeline
run_pipeline(PROJECT_ROOT)

# %%
import sqlite3, pandas as pd
con = sqlite3.connect("data/processed/netflix_analytics.db")
pd.read_sql_query("SELECT * FROM summary_metrics", con)

# %%
pd.read_sql_query("SELECT * FROM churn_by_activity", con)
